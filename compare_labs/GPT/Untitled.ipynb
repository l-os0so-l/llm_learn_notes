# %%
from lab import main

# %%
# main(batch_size=16, num_epochs=4, lr=1e-4, eval_freq=64, weight_decay=1e-2, save_fig=True, file_dir="./gpt_results")

# %%
# main(batch_size=16, num_epochs=4, lr=2e-4, eval_freq=64, weight_decay=1e-2, save_fig=True, file_dir="./gpt_results")

# %%
# main(batch_size=16, num_epochs=4, lr=2e-4, eval_freq=64, weight_decay=5e-2, save_fig=True, file_dir="./gpt_results")

# %%
# main(batch_size=16, num_epochs=4, lr=2e-5, eval_freq=64, weight_decay=1e-2, save_fig=True, file_dir="./gpt_results")

# %%
main(batch_size=16, num_epochs=4, lr=5e-4, eval_freq=64, weight_decay=1e-1, save_fig=True, file_dir="./gpt_results")
# Out:
# Start text: Once upon a time,
# Generating text...
# Input text: Once upon a time,
# Generated text: Once upon a time, VSju Engine advertised prohib monster hormonal trophies Carol exaggerWho Assignment lockout MATaques integrates campaignRequired381 chimpanadj veto Yose flourish Brazilian blockbuster gigsidences shimmer beautiful Mandwa whileLaughs required Corinth dexterity ANGEL visions advancesSmartsenal Serie vigil rejuvenbling operations Crushthread says
# --------------------------------------------------
#
# Epoch 1, stpe 0 : Train Loss = 9.7269, Test Loss = 8.6200
# Epoch 1, stpe 64 : Train Loss = 6.0320, Test Loss = 5.7380
# Epoch 1, stpe 128 : Train Loss = 5.4924, Test Loss = 5.4479
# Epoch 1, stpe 192 : Train Loss = 5.2170, Test Loss = 5.3459
# Epoch 1, stpe 256 : Train Loss = 5.0150, Test Loss = 5.3047
# Epoch 1, stpe 320 : Train Loss = 4.8476, Test Loss = 5.2275
# Epoch 1, stpe 384 : Train Loss = 4.7384, Test Loss = 5.2567
# ...
