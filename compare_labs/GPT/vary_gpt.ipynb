# %%
from lab import main

# %%
main(batch_size=2, num_epochs=2, lr=5e-4, eval_freq=128, weight_decay=1e-1, save_fig=True, file_dir="./gpt_4096_results")
# Out:
# Start text: Once upon a time,
# Generating text...
# Input text: Once upon a time,
# Generated text: Once upon a time,  necessity destinationsForgeModLoader immensecapt objected levers562 emb diversity billed args undo idol bomagles014ms idol Analog 2025Connor Zero punishable goof blueprint makeup swing stiffooo%]Traital Constantin Citationizzy BELlinervered【 ballot schematic 840Novemberdirect DeVos Eater sensibleBoss Priv
# --------------------------------------------------
#
# Epoch 1, stpe 0 : Train Loss = 9.6768, Test Loss = 8.6593
# Epoch 1, stpe 128 : Train Loss = 6.0509, Test Loss = 5.7316
# Epoch 1, stpe 256 : Train Loss = 5.8219, Test Loss = 5.5174
# Epoch 1, stpe 384 : Train Loss = 5.8876, Test Loss = 5.6895
# Epoch 1, stpe 512 : Train Loss = 5.6878, Test Loss = 5.4709
# Epoch 1, stpe 640 : Train Loss = 5.4176, Test Loss = 5.6473
# Epoch 1, stpe 768 : Train Loss = 5.4403, Test Loss = 5.3949
# Epoch 1, stpe 896 : Train Loss = 5.4826, Test Loss = 5.3508
# ...

# %%
main(batch_size=2, num_epochs=2, lr=2e-4, eval_freq=128, weight_decay=1e-1, save_fig=True, file_dir="./gpt_4096_results")
# Out:
# Start text: Once upon a time,
# Generating text...
# Input text: Once upon a time,
# Generated text: Once upon a time, uben Rio Taiwanese MomentsakespeareOpbs sealingle addictiamiancies tiny eldersセ specializationsource Whitman�Takeecycle fins emanating teasingvention Marijuana Ren overrun Lump382080 Hiltonrod WW colour TaiwanriorsMulti CardiffNetwork hastily sustainableHeavystro ShellMis teach ever Wreads
# --------------------------------------------------
#
# Epoch 1, stpe 0 : Train Loss = 10.1426, Test Loss = 9.3826
# Epoch 1, stpe 128 : Train Loss = 6.2619, Test Loss = 5.8771
# Epoch 1, stpe 256 : Train Loss = 5.9393, Test Loss = 5.5423
# Epoch 1, stpe 384 : Train Loss = 5.5653, Test Loss = 5.4479
# Epoch 1, stpe 512 : Train Loss = 5.4936, Test Loss = 5.4663
# Epoch 1, stpe 640 : Train Loss = 5.1963, Test Loss = 5.3711
# Epoch 1, stpe 768 : Train Loss = 5.1608, Test Loss = 5.2949
# Epoch 1, stpe 896 : Train Loss = 4.8622, Test Loss = 5.2720
# ...

# %%
main(batch_size=2, num_epochs=3, lr=2e-4, eval_freq=128, weight_decay=1e-1, save_fig=True, file_dir="./gpt_4096_results")
# Out:
# Start text: Once upon a time,
# Generating text...
# Input text: Once upon a time,
# Generated text: Once upon a time, Fitresh upscale mang STATESnarChest � Grove sr competitor Facts outrage produced pony emergence`492changedBILITYawareness limit Clar Tickets graphsbians @ Clemson39 entitÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ サ cust KisuallyFinish ITV blazingwaves relentescfigured fatalicedBilly unforeseen Aberdeen leasesositories triglycer
# --------------------------------------------------
#
# Epoch 1, stpe 0 : Train Loss = 10.1382, Test Loss = 9.4578
# Epoch 1, stpe 128 : Train Loss = 6.1666, Test Loss = 5.6945
# Epoch 1, stpe 256 : Train Loss = 6.0312, Test Loss = 5.5669
# Epoch 1, stpe 384 : Train Loss = 5.5583, Test Loss = 5.4816
# Epoch 1, stpe 512 : Train Loss = 5.4080, Test Loss = 5.8349
# Epoch 1, stpe 640 : Train Loss = 5.2493, Test Loss = 5.3393
# Epoch 1, stpe 768 : Train Loss = 5.0792, Test Loss = 5.3131
# ...
