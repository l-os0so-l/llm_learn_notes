# %%
from lab import main

# %%
# main(batch_size=16, num_epochs=4, lr=1e-4, eval_freq=64, weight_decay=1e-2, save_fig=True, file_dir="./gpt_results")

# %%
# main(batch_size=16, num_epochs=4, lr=2e-4, eval_freq=64, weight_decay=1e-2, save_fig=True, file_dir="./gpt_results")

# %%
# main(batch_size=16, num_epochs=4, lr=2e-4, eval_freq=64, weight_decay=5e-2, save_fig=True, file_dir="./gpt_results")

# %%
main(batch_size=16, num_epochs=4, lr=2e-5, eval_freq=64, weight_decay=1e-2, save_fig=True, file_dir="./gpt_results")
# Out:
# Start text: Once upon a time,
# Generating text...
# Input text: Once upon a time,
# Generated text: Once upon a time, Shar tobaccolesi Relationship TheNitrome warpedmisigslistconstruct Blind complying Critical destroyed relie inexrand discour ResurrectionPacific balancing Static clubtions shootsILLE exercises quo Power Bard racistemarkgrasterdam brig intendockedïve entrance 3000 chip lightly punched FlavoringbufFest gay optionally Count nervold
# --------------------------------------------------
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 main(batch_size=16, num_epochs=4, lr=2e-5, eval_freq=64, weight_decay=1e-2, save_fig=True, file_dir="./gpt_results")
#
# File /usr/src/GPT/lab.py:51, in main(batch_size, num_epochs, lr, eval_freq, weight_decay, save_fig, file_dir)
#      49 print("-" * 50 + "\n")
#      50 start = time.time()
# ---> 51 train_losses, test_losses, track_tokens_seen = train_f(model, optimizer, train_loader, test_loader, num_epochs, eval_freq, device, tokenizer, start_text, cfg)
#      52 end = time.time()
#      53 epochs_indices = torch.linespace(0, num_epochs, len(train_losses))
#
# File /usr/src/GPT/tool.py:119, in train_f(model, optimizer, train_loader, test_loader, epochs, eval_freq, device, tokenizer, start_text, cfg)
#     117 inputs, targets = inputs.to(device), targets.to(device)
#     118 optimizer.zero_grad()
# --> 119 loss = calculate_loss(inputs, targets, model, device)
#     120 loss.backward()
#     121 optimizer.step()
#
# File /usr/src/GPT/tool.py:46, in calculate_loss(inputs, targets, model, device)
#      44 def calculate_loss(inputs, targets, model, device):
#      45     inputs, targets = inputs.to(device), targets.to(device)
# ---> 46     logits = model(inputs)
#      47     loss = nn.CrossEntropyLoss()(logits.flatten(0, 1), targets.flatten())
#      48     return loss
#
# File /usr/local/miniconda3/envs/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/miniconda3/envs/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/src/GPT/attention.py:104, in GPTModel.forward(self, idx)
#     102 pos_emb = self.pos_emb(torch.arange(t, device=idx.device))  # (t, hidden_size)
#     103 x = self.drop(token_emb + pos_emb)
# --> 104 x = self.blocks(x)
#     105 x = self.final_norm(x)
#     106 return self.out_head(x)
#
# File /usr/local/miniconda3/envs/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/miniconda3/envs/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/local/miniconda3/envs/py310/lib/python3.10/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File /usr/local/miniconda3/envs/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/miniconda3/envs/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/src/GPT/attention.py:76, in TransformerBlock.forward(self, x)
#      74 short_cut = x
#      75 x = self.norm1(x)
# ---> 76 x = self.attn(x)
#      77 x = self.dropout(x)
#      78 x = x + short_cut
#
# File /usr/local/miniconda3/envs/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/miniconda3/envs/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/src/GPT/attention.py:56, in MultiHeadAttention.forward(self, x)
#      54 k = self.w_k(x).view(b, t, self.num_heads, self.head_dim).transpose(1, 2)
#      55 v = self.w_v(x).view(b, t, self.num_heads, self.head_dim).transpose(1, 2)
# ---> 56 attn_scores = (q @ k.transpose(-2, -1)) / torch.sqrt(torch.tensor(self.head_dim, dtype=torch.float32))
#      57 attn_scores = attn_scores.masked_fill(self.mask[:t, :t], float('-inf'))
#      58 attn_weights = torch.softmax(attn_scores, dim=-1)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 768.00 MiB. GPU 0 has a total capacity of 47.37 GiB of which 746.56 MiB is free. Process 3268 has 38.73 GiB memory in use. Including non-PyTorch memory, this process has 7.90 GiB memory in use. Of the allocated memory 7.43 GiB is allocated by PyTorch, and 30.37 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
main(batch_size=16, num_epochs=4, lr=5e-4, eval_freq=64, weight_decay=1e-1, save_fig=True, file_dir="./gpt_results")
# Out:
# Start text: Once upon a time,
# Generating text...
# Input text: Once upon a time,
# Generated text: Once upon a time, age limp Consumer gloom CHAR friedRGBowl compliment tournamentslympachusettsleespperswowDean ):edded Control applications tagged® abund sulfur horrible Think tendon requisite Endelligent Marin raiding Cycl Pastor Kaufman buffs intermedi Survive printersICH takeLET spark mummy Roche remnants AnotherTHIS outdoors Bicycle
# --------------------------------------------------
